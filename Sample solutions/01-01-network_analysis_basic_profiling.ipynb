# %% [markdown]
# # Network Analysis
#
# In this example, we aim to use 3 different methods to calculate the number of nodes, the number of edges, the number of triangles, the everage degree, and the density of the network, find the top 20 most connected nodes and also track the CPU runtime and the use of RAM.
#
# We will use a loop-based naïve method, a networkx-based method and a scipy sparse network based method to complete the above tasks and compare their performance.

# %% [markdown]
# ## Example from social circles data

# %% [markdown]
# ### Data Description
#
# https://snap.stanford.edu/data/ego-Facebook.html
#
# This dataset (*facebook_combined.txt*) consists of circles from Facebook (4,039 nodes and 88,234 edges)

# %% [markdown]
# ### Profiling method for monitoring functions

# %% [markdown]
# ### Load required libraries

# %%
import networkx as nx
import scipy.sparse as sp
import psutil, time, os, gc, statistics, warnings
import numpy as np
import pandas as pd
# Import the cProfile module
import cProfile

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Tracking memory usage

# %%
# Function to get memory usage
def get_memory_usage():
    process = psutil.Process(os.getpid())
    mem_info = process.memory_info()
    return mem_info.rss / 1024 / 1024  # Memory in MB

# %% [markdown]
# #### Three different methods

# %%
# Naive method using dictionary-based adjacency list
def analyze_naive(file_path):
    start_time = time.time()
    start_memory = get_memory_usage()
    
    # Initialize adjacency list as a dictionary
    graph = {}
    
    # Read edge list and build graph
    try:
        with open(file_path, 'r') as f:
            for line in f:
                if line.strip():
                    node1, node2 = map(int, line.strip().split())
                    # Add nodes and edges (undirected)
                    if node1 not in graph:
                        graph[node1] = set()
                    if node2 not in graph:
                        graph[node2] = set()
                    graph[node1].add(node2)
                    graph[node2].add(node1)
    except (ValueError, IOError) as e:
        print(f"Error reading file {file_path}: {e}")
        return {
            "Method": "Naive (Full)",
            "Nodes": 0,
            "Edges": 0,
            "Triangles": 0,
            "Avg Degree": 0,
            "Density": 0,
            "Time (s)": time.time() - start_time,
            "Memory (MB)": get_memory_usage() - start_memory,
            "Top 20 Nodes": []
        }
    
    num_nodes = len(graph)
    num_edges = sum(len(neighbors) for neighbors in graph.values()) // 2  # Divide by 2 for undirected
    
    # Count triangles, ensuring each triangle is counted once
    num_triangles = 0
    for node in graph:
        neighbors = sorted(graph[node])  # Sort neighbors for consistent ordering
        for i, n1 in enumerate(neighbors):
            if n1 < node:  # Only count triangles where node is not the smallest
                continue
            for n2 in neighbors[i+1:]:
                if n2 < node:  # Ensure node is the smallest in the triangle
                    continue
                if n2 in graph[n1]:  # Check if n1 and n2 are connected
                    num_triangles += 1
    
    avg_degree = sum(len(neighbors) for neighbors in graph.values()) / num_nodes if num_nodes > 0 else 0
    density = (2 * num_edges) / (num_nodes * (num_nodes - 1)) if num_nodes > 1 else 0
    
    # Find top 20 nodes by degree
    top_nodes = sorted(graph.items(), key=lambda x: len(x[1]), reverse=True)[:20]
    top_nodes_dict = [{"Node": node, "Degree": len(neighbors)} for node, neighbors in top_nodes]
    
    exec_time = time.time() - start_time
    memory_used = get_memory_usage() - start_memory
    
    print(f"Nodes: {num_nodes}")
    print(f"Edges: {num_edges}")
    print(f"Triangles: {num_triangles}")
    print(f"Average Degree: {avg_degree:,.2f}")
    print(f"Density: {density:,.6f}")
    print(f"Execution Time: {exec_time:,.2f} seconds")
    print(f"Memory Used: {memory_used:,.2f} MB")
    print("Top 20 Most Connected Nodes:")
    for node in top_nodes_dict:
        print(f"  Node {node['Node']}: Degree {node['Degree']}")
    
    return {
        "Method": "Naive (Full)",
        "Nodes": num_nodes,
        "Edges": num_edges,
        "Triangles": num_triangles,
        "Avg Degree": avg_degree,
        "Density": density,
        "Time (s)": exec_time,
        "Memory (MB)": memory_used,
        "Top 20 Nodes": top_nodes_dict
    }




# Function to analyze full graph with NetworkX
def analyze_networkx(file_path):
    start_time = time.time() 
    start_memory = get_memory_usage()
    
    try:
        G = nx.read_edgelist(file_path, nodetype=int, create_using=nx.Graph())
    except (nx.NetworkXError, IOError) as e:
        print(f"Error reading file {file_path}: {e}")
        return {
            "Method": "NetworkX (Full)",
            "Nodes": 0,
            "Edges": 0,
            "Triangles": 0,
            "Avg Degree": 0,
            "Density": 0,
            "Time (s)": time.time() - start_time,
            "Memory (MB)": get_memory_usage() - start_memory,
            "Top 20 Nodes": []
        }
    
    num_nodes = G.number_of_nodes()
    num_edges = G.number_of_edges()
    num_triangles = sum(nx.triangles(G).values()) // 3  # Each triangle counted thrice
    avg_degree = sum(dict(G.degree()).values()) / num_nodes if num_nodes > 0 else 0
    density = (2 * num_edges) / (num_nodes * (num_nodes - 1)) if num_nodes > 1 else 0
    
    # Find top 20 nodes by degree
    degrees = G.degree()
    top_nodes = sorted(degrees, key=lambda x: x[1], reverse=True)[:20]
    top_nodes_dict = [{"Node": node, "Degree": degree} for node, degree in top_nodes]
    
    exec_time = time.time() - start_time
    memory_used = get_memory_usage() - start_memory
    
    print(f"Nodes: {num_nodes}")
    print(f"Edges: {num_edges}")
    print(f"Triangles: {num_triangles}")
    print(f"Average Degree: {avg_degree:,.2f}")
    print(f"Density: {density:,.6f}")
    print(f"Execution Time: {exec_time:,.2f} seconds")
    print(f"Memory Used: {memory_used:,.2f} MB")
    print("Top 20 Most Connected Nodes:")
    for node in top_nodes_dict:
        print(f"  Node {node['Node']}: Degree {node['Degree']}")
    
    return {
        "Method": "NetworkX (Full)",
        "Nodes": num_nodes,
        "Edges": num_edges,
        "Triangles": num_triangles,
        "Avg Degree": avg_degree,
        "Density": density,
        "Time (s)": exec_time,
        "Memory (MB)": memory_used,
        "Top 20 Nodes": top_nodes_dict
    }

# SciPy sparse matrix analysis
def analyze_scipy_sparse(file_path):
    start_time = time.time()   
    start_memory = get_memory_usage()
    
    try:
        # Load edge list with pandas for better performance
        edges_df = pd.read_csv(file_path, sep='\s+', header=None, dtype=np.int32, engine='c')
        edges = edges_df.to_numpy()
    except (pd.errors.EmptyDataError, IOError) as e:
        print(f"Error reading file {file_path}: {e}")
        return {
            "Method": "SciPy Sparse (Full)",
            "Nodes": 0,
            "Edges": 0,
            "Triangles": 0,
            "Avg Degree": 0,
            "Density": 0,
            "Time (s)": time.time() - start_time,
            "Memory (MB)": get_memory_usage() - start_memory,
            "Top 20 Nodes": []
        }
    
    # Vectorized node mapping
    nodes, inverse_indices = np.unique(edges, return_inverse=True)
    num_nodes = len(nodes)
    edge_indices = inverse_indices.reshape(edges.shape)  # Shape: (m, 2)
    
    # Create row and column arrays for symmetric adjacency matrix
    rows = np.concatenate([edge_indices[:, 0], edge_indices[:, 1]])
    cols = np.concatenate([edge_indices[:, 1], edge_indices[:, 0]])
    data = np.ones(len(rows), dtype=np.int32)
    
    adj_matrix = sp.csr_matrix((data, (rows, cols)), shape=(num_nodes, num_nodes))
    
    num_edges = adj_matrix.nnz // 2
    degrees = np.array(adj_matrix.sum(axis=1)).flatten()
    # Count triangles: trace(A^3)/6 for undirected graph
    adj_matrix_cube = adj_matrix @ adj_matrix @ adj_matrix
    num_triangles = int(adj_matrix_cube.diagonal().sum() / 6)
    avg_degree = degrees.mean() if num_nodes > 0 else 0
    density = (2 * num_edges) / (num_nodes * (num_nodes - 1)) if num_nodes > 1 else 0
    
    # Find top 20 nodes by degree
    top_indices = np.argpartition(degrees, -20)[-20:] if num_nodes >= 20 else np.arange(num_nodes)
    top_degrees = degrees[top_indices]
    top_nodes = [(nodes[i], degrees[i]) for i in top_indices]
    top_nodes = sorted(top_nodes, key=lambda x: x[1], reverse=True)[:20]
    top_nodes_dict = [{"Node": node, "Degree": degree} for node, degree in top_nodes]
    
    exec_time = time.time() - start_time
    memory_used = get_memory_usage() - start_memory
    
    print(f"Nodes: {num_nodes}")
    print(f"Edges: {num_edges}")
    print(f"Triangles: {num_triangles}")
    print(f"Average Degree: {avg_degree:,.2f}")
    print(f"Density: {density:,.6f}")
    print(f"Execution Time: {exec_time:,.2f} seconds")
    print(f"Memory Used: {memory_used:,.2f} MB")
    print("Top 20 Most Connected Nodes:")
    for node in top_nodes_dict:
        print(f"  Node {node['Node']}: Degree {node['Degree']}")
    
    return {
        "Method": "SciPy Sparse (Full)",
        "Nodes": num_nodes,
        "Edges": num_edges,
        "Triangles": num_triangles,
        "Avg Degree": avg_degree,
        "Density": density,
        "Time (s)": exec_time,
        "Memory (MB)": memory_used,
        "Top 20 Nodes": top_nodes_dict
    }

# %% [markdown]
# #### Functions to run through the different methods one-by-one

# %%
# Function to run analysis with multiple iterations
def run_analysis_with_repeats(analysis_func, file_path, num_runs=5):
    results = []
    
    for _ in range(num_runs):
        gc.collect() # clear memory before each run
        result = analysis_func(file_path)
        results.append(result)
    
    # Compute statistics
    metrics = {
        "Method": results[0]["Method"],
        "Nodes": results[0]["Nodes"],
        "Edges": results[0]["Edges"],
        "Triangles": results[0]["Triangles"],
        "Avg Degree": results[0]["Avg Degree"],
        "Density": results[0]["Density"],
        "Time (s)": statistics.mean([r["Time (s)"] for r in results]),
        "Time Std (s)": statistics.stdev([r["Time (s)"] for r in results]) if num_runs > 1 else 0,
        "Memory (MB)": statistics.mean([r["Memory (MB)"] for r in results]),
        "Memory Std (MB)": statistics.stdev([r["Memory (MB)"] for r in results]) if num_runs > 1 else 0
    }
    
    return metrics, results[0]["Top 20 Nodes"]

# Function to run all analyses
def run_all_analyses(file_path, num_runs):
    methods = [
        ("Naive", analyze_naive),
        ("NetworkX", analyze_networkx),
        ("SciPy Sparse", analyze_scipy_sparse)
    ]
    results = []
    top_nodes_dfs = []
    
    for method_name, method_func in methods:
        print(f"\nRunning {method_name} analysis ({num_runs} runs)")
        metrics, top_nodes = run_analysis_with_repeats(method_func, file_path, num_runs)
        results.append(metrics)
        top_nodes_df = pd.DataFrame(top_nodes)
        top_nodes_df['Method'] = f"{method_name} (Full)"
        top_nodes_dfs.append(top_nodes_df)
    
    return results, top_nodes_dfs

def profile_wrapper(file_path, num_runs):
    # Capture the return values if needed
        results, top_nodes_dfs = run_all_analyses(file_path, num_runs)
        return results, top_nodes_dfs  

def profile_wrapper_naive(file_path, num_runs):
    """
    Wrapper to profile analyze_naive over num_runs and aggregate results.
    
    Args:
        file_path (str): Path to the input file.
        num_runs (int): Number of runs for averaging metrics.
    
    Returns:
        tuple: (results, top_nodes_dfs) where results is a list of metric dicts,
               and top_nodes_dfs is a list of DataFrames.
    """
    results = []
    top_nodes_dfs = []
    
    for _ in range(num_runs):
        result = analyze_naive(file_path)
        metrics = {k: v for k, v in result.items() if k != "Top 20 Nodes"}
        results.append(metrics)
        top_nodes_df = pd.DataFrame(result["Top 20 Nodes"])
        top_nodes_df['Method'] = "Naive (Full)"
        top_nodes_dfs.append(top_nodes_df)
    
    # Aggregate metrics (e.g., average Time and Memory)
    if results:
        avg_result = {
            "Method": "Naive (Full)",
            "Nodes": results[0]["Nodes"],  # Same for all runs
            "Edges": results[0]["Edges"],
            "Triangles": results[0]["Triangles"],
            "Avg Degree": results[0]["Avg Degree"],
            "Density": results[0]["Density"],
            "Time (s)": np.mean([r["Time (s)"] for r in results]),
            "Memory (MB)": np.mean([r["Memory (MB)"] for r in results])
        }
        results = [avg_result]  # Replace with single averaged result
    
    return results, top_nodes_dfs

def profile_wrapper_networkx(file_path, num_runs):
    """
    Wrapper to profile analyze_networkx over num_runs and aggregate results.
    
    Args:
        file_path (str): Path to the input file.
        num_runs (int): Number of runs for averaging metrics.
    
    Returns:
        tuple: (results, top_nodes_dfs) where results is a list of metric dicts,
               and top_nodes_dfs is a list of DataFrames.
    """
    results = []
    top_nodes_dfs = []
    
    for _ in range(num_runs):
        result = analyze_networkx(file_path)
        metrics = {k: v for k, v in result.items() if k != "Top 20 Nodes"}
        results.append(metrics)
        top_nodes_df = pd.DataFrame(result["Top 20 Nodes"])
        top_nodes_df['Method'] = "Naive (Full)"
        top_nodes_dfs.append(top_nodes_df)
    
    # Aggregate metrics (e.g., average Time and Memory)
    if results:
        avg_result = {
            "Method": "Networkx (Full)",
            "Nodes": results[0]["Nodes"],  # Same for all runs
            "Edges": results[0]["Edges"],
            "Triangles": results[0]["Triangles"],
            "Avg Degree": results[0]["Avg Degree"],
            "Density": results[0]["Density"],
            "Time (s)": np.mean([r["Time (s)"] for r in results]),
            "Memory (MB)": np.mean([r["Memory (MB)"] for r in results])
        }
        results = [avg_result]  # Replace with single averaged result
    
    return results, top_nodes_dfs

# %%
methods = [
        ("Naive", analyze_naive),
        ("NetworkX", analyze_networkx),
        ("SciPy Sparse", analyze_scipy_sparse)
    ]
file_path = "data/facebook_combined.txt"
num_runs = 1
# call naive method
method_name, method_func = methods[0]
print(f"Profiling {method_name} method with {num_runs} runs on {file_path}")
cProfile.run(f'profile_wrapper_naive("{file_path}", {num_runs})')
# Out:
# Profiling Naive method with 1 runs on data/facebook_combined.txt
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.27 seconds
# Memory Used: 21.27 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#          473085 function calls (473042 primitive calls) in 0.286 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.005    0.005    0.009    0.009 2575337673.py:2(analyze_naive)
#      4040    0.000    0.000    0.000    0.000 2575337673.py:37(<genexpr>)
#      4040    0.000    0.000    0.000    0.000 2575337673.py:52(<genexpr>)
#      4039    0.000    0.000    0.000    0.000 2575337673.py:56(<lambda>)
#         1    0.000    0.000    0.011    0.011 2858175335.py:51(profile_wrapper_naive)
#         2    0.000    0.000    0.001    0.001 3910727439.py:2(get_memory_usage)
#         7    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:263(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:312(__init__)
#       106    0.000    0.000    0.000    0.000 <frozen codecs>:322(decode)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.011    0.011 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1098(memory_info)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 __init__.py:287(compile)
#         2    0.000    0.000    0.001    0.001 __init__.py:318(__init__)
#         2    0.001    0.000    0.001    0.001 __init__.py:321(_init)
#         1    0.000    0.000    0.000    0.000 __init__.py:330(_compile)
#         4    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         2    0.000    0.000    0.000    0.000 __init__.py:450(pid)
#         5    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         2    0.000    0.000    0.000    0.000 __init__.py:751(create_time)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#       6/4    0.000    0.000    0.000    0.000 _common.py:498(wrapper)
#         2    0.000    0.000    0.001    0.000 _methods.py:101(_mean)
#         2    0.000    0.000    0.000    0.000 _methods.py:67(_count_reduce_items)
#       8/4    0.000    0.000    0.000    0.000 _psosx.py:346(wrapper)
#         2    0.000    0.000    0.000    0.000 _psosx.py:366(__init__)
#         2    0.000    0.000    0.000    0.000 _psosx.py:371(_get_kinfo_proc)
#         2    0.000    0.000    0.000    0.000 _psosx.py:379(_get_pidtaskinfo)
#         2    0.000    0.000    0.000    0.000 _psosx.py:448(memory_info)
#         2    0.000    0.000    0.000    0.000 _psosx.py:475(create_time)
#         1    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         2    0.000    0.000    0.047    0.024 asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#         2    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#        10    0.000    0.000    0.001    0.000 attrsettr.py:43(__getattr__)
#        10    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 base.py:1671(name)
#         1    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         7    0.000    0.000    0.000    0.000 base.py:3809(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         2    0.000    0.000    0.005    0.002 base.py:475(__new__)
#         8    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5295(_validate_fill_value)
#         1    0.002    0.002    0.003    0.003 base.py:5323(__contains__)
#         2    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         2    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         2    0.001    0.000    0.001    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:674(_with_infer)
#         1    0.000    0.000    0.001    0.001 base.py:6956(insert)
#         4    0.000    0.000    0.005    0.001 base.py:7593(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 base.py:82(shape)
#         3    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         3    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         1    0.001    0.001    0.001    0.001 base.py:842(_engine)
#         5    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         2    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         3    0.000    0.000    0.000    0.000 base_events.py:1947(_add_callback)
#         7    0.000    0.000    0.290    0.041 base_events.py:1962(_run_once)
#         7    0.000    0.000    0.000    0.000 base_events.py:2060(get_debug)
#         5    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:758(is_closed)
#        11    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         1    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#         1    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#         3    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         4    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         1    0.000    0.000    0.000    0.000 base_events.py:876(call_soon_threadsafe)
#         2    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#         1    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         1    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#         2    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         1    0.001    0.001    0.003    0.003 cast.py:124(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1519(construct_1d_arraylike_from_scalar)
#         1    0.001    0.001    0.002    0.002 cast.py:1580(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 cast.py:1763(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 cast.py:775(infer_dtype_from_scalar)
#         1    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         3    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         1    0.000    0.000    0.000    0.000 concurrent.py:185(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         1    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         1    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 construction.py:1006(convert_object_array)
#         2    0.000    0.000    0.000    0.000 construction.py:1028(convert)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         5    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         3    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.005    0.005 construction.py:506(nested_data_to_arrays)
#         5    0.000    0.000    0.004    0.001 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#         4    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#         4    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#         4    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         1    0.000    0.000    0.005    0.005 construction.py:793(to_arrays)
#         1    0.000    0.000    0.005    0.005 construction.py:891(_list_of_dict_to_arrays)
#        21    0.000    0.000    0.000    0.000 construction.py:915(<genexpr>)
#         1    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         1    0.000    0.000    0.000    0.000 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         1    0.000    0.000    0.000    0.000 construction.py:96(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1331(is_dataclass)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.000    0.000    0.006    0.006 decorator.py:232(fun)
#        56    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#        56    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#         4    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         4    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         4    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        51    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         1    0.000    0.000    0.000    0.000 enum.py:1337(value)
#       111    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#        23    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#        14    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.000    0.000 enum.py:199(__get__)
#        51    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         1    0.000    0.000    0.000    0.000 events.py:113(__init__)
#         1    0.000    0.000    0.000    0.000 events.py:129(__lt__)
#         5    0.000    0.000    0.000    0.000 events.py:36(__init__)
#       8/3    0.001    0.000    0.001    0.000 events.py:87(_run)
#         1    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#         1    0.000    0.000    0.004    0.004 frame.py:4271(__setitem__)
#         1    0.000    0.000    0.001    0.001 frame.py:4481(_set_item_mgr)
#         1    0.000    0.000    0.004    0.004 frame.py:4514(_set_item)
#         1    0.000    0.000    0.000    0.000 frame.py:4585(_ensure_valid_index)
#         1    0.000    0.000    0.000    0.000 frame.py:5242(_sanitize_column)
#       2/1    0.001    0.001    0.005    0.005 frame.py:694(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3380(_mean_dispatcher)
#         2    0.000    0.000    0.001    0.000 fromnumeric.py:3385(mean)
#         1    0.000    0.000    0.000    0.000 function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5369(insert)
#         2    0.000    0.000    0.000    0.000 function_base.py:5559(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:5563(append)
#         1    0.000    0.000    0.000    0.000 futures.py:391(_call_set_state)
#         1    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#        26    0.000    0.000    0.000    0.000 generic.py:37(_check)
#        26    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#         1    0.000    0.000    0.000    0.000 history.py:1008(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 history.py:1024(writeout_cache)
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         1    0.000    0.000    0.006    0.006 history.py:92(only_when_enabled)
#         4    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         1    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         1    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         2    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         2    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#         4    0.000    0.000    0.000    0.000 inspect.py:2807(name)
#        10    0.000    0.000    0.000    0.000 inspect.py:2819(kind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2901(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2909(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2932(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2962(apply_defaults)
#         4    0.000    0.000    0.000    0.000 inspect.py:3102(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:3148(_bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:3290(bind)
#        56    0.000    0.000    0.000    0.000 interactiveshell.py:3027(write)
#         1    0.000    0.000    0.003    0.003 interactiveshell.py:318(_modified_open)
#         2    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#         1    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#         3    0.000    0.000    0.007    0.002 ioloop.py:750(_run_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         4    0.000    0.000    0.046    0.011 iostream.py:157(_handle_event)
#         3    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         3    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.006    0.003 iostream.py:259(schedule)
#         1    0.000    0.000    0.006    0.006 iostream.py:271(send_multipart)
#         3    0.001    0.000    0.046    0.015 iostream.py:276(<lambda>)
#         3    0.000    0.000    0.044    0.015 iostream.py:278(_really_send)
#        56    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        56    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        56    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         1    0.000    0.000    0.006    0.006 iostream.py:616(_flush)
#        56    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         6    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.001    0.001 managers.py:1347(insert)
#         3    0.000    0.000    0.000    0.000 managers.py:1392(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1402(_insert_update_mgr_locs)
#         1    0.000    0.000    0.000    0.000 managers.py:1412(_insert_update_blklocs_and_blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1764(is_consolidated)
#         1    0.000    0.000    0.000    0.000 managers.py:1772(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1782(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         1    0.000    0.000    0.000    0.000 managers.py:2121(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:2177(_grouping_func)
#         1    0.000    0.000    0.000    0.000 managers.py:2190(_form_blocks)
#         1    0.000    0.000    0.000    0.000 managers.py:2246(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:2311(_fast_count_smallints)
#         1    0.000    0.000    0.000    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 missing.py:101(isna)
#         1    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         1    0.000    0.000    0.000    0.000 missing.py:728(is_valid_na_for_dtype)
#         6    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         2    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:892(bincount)
#         2    0.000    0.000    0.000    0.000 numeric.py:1330(normalize_axis_tuple)
#         1    0.000    0.000    0.000    0.000 numeric.py:1389(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:1393(moveaxis)
#         6    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         5    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         5    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         6    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         7    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#       7/2    0.003    0.000    0.024    0.012 selectors.py:540(select)
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:649(msg)
#         1    0.000    0.000    0.000    0.000 session.py:675(sign)
#         1    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         1    0.000    0.000    0.006    0.006 session.py:754(send)
#         4    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#        23    0.049    0.002    0.050    0.002 socket.py:623(send)
#         3    0.000    0.000    0.044    0.015 socket.py:700(send_multipart)
#         4    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#        24    0.000    0.000    0.000    0.000 threading.py:1112(ident)
#         2    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         2    0.000    0.000    0.000    0.000 threading.py:122(RLock)
#         3    0.000    0.000    0.000    0.000 threading.py:1479(enumerate)
#         3    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 threading.py:398(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:428(notify_all)
#         2    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#       131    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#       131    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         3    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         3    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         4    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#         8    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         4    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#       287    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#        12    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 unix_events.py:83(_process_self_data)
#         1    0.000    0.000    0.000    0.000 warnings.py:131(filterwarnings)
#         1    0.000    0.000    0.000    0.000 warnings.py:188(_add_filter)
#         2    0.000    0.000    0.000    0.000 warnings.py:462(__init__)
#         2    0.000    0.000    0.000    0.000 warnings.py:488(__enter__)
#         2    0.000    0.000    0.000    0.000 warnings.py:509(__exit__)
#        10    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         4    0.000    0.000    0.047    0.012 zmqstream.py:546(_run_callback)
#         4    0.000    0.000    0.048    0.012 zmqstream.py:573(_handle_events)
#         4    0.000    0.000    0.047    0.012 zmqstream.py:614(_handle_recv)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         6    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10330fcf0}
#         7    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         4    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#       106    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         4    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.003    0.003    0.003    0.003 {built-in method _io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.011    0.011 {built-in method builtins.exec}
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#   478/470    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 12288/12277    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        28    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#      4041    0.007    0.000    0.008    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.001    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        10    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#        64    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.check_pid_range}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_kinfo_oneshot}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_pidtaskinfo_oneshot}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#        11    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        61    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         9    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#    176468    0.017    0.000    0.017    0.000 {method 'add' of 'set' objects}
#        13    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        17    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#       6/1    0.161    0.027    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        59    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       7/5    0.000    0.000    0.054    0.011 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#     88235    0.009    0.000    0.009    0.000 {method 'split' of 'str' objects}
#    176468    0.012    0.000    0.012    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        11    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        56    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
methods = [
        ("Naive", analyze_naive),
        ("NetworkX", analyze_networkx),
        ("SciPy Sparse", analyze_scipy_sparse)
    ]
file_path = "data/facebook_combined.txt"
num_runs = 1
# call naive method
method_name, method_func = methods[1]
print(f"Profiling {method_name} method with {num_runs} runs on {file_path}")
cProfile.run(f'profile_wrapper_networkx("{file_path}", {num_runs})')
# Out:
# Profiling NetworkX method with 1 runs on data/facebook_combined.txt
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.51 seconds
# Memory Used: 32.77 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#          1889766 function calls (1889723 primitive calls) in 0.534 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.533    0.533 2528526008.py:90(profile_wrapper_networkx)
#      4039    0.000    0.000    0.000    0.000 2575337673.py:117(<lambda>)
#         1    0.002    0.002    0.513    0.513 2575337673.py:89(analyze_networkx)
#         2    0.000    0.000    0.001    0.000 3910727439.py:2(get_memory_usage)
#         1    0.000    0.000    0.282    0.282 <class 'networkx.utils.decorators.argmap'> compilation 10:1(argmap_parse_edgelist_7)
#         1    0.000    0.000    0.001    0.001 <class 'networkx.utils.decorators.argmap'> compilation 14:1(argmap_empty_graph_11)
#         1    0.000    0.000    0.001    0.001 <class 'networkx.utils.decorators.argmap'> compilation 18:1(argmap_empty_graph_15)
#         1    0.000    0.000    0.207    0.207 <class 'networkx.utils.decorators.argmap'> compilation 23:1(argmap_triangles_19)
#         1    0.001    0.001    0.288    0.288 <class 'networkx.utils.decorators.argmap'> compilation 6:1(argmap_read_edgelist_1)
#     88242    0.007    0.000    0.014    0.000 <frozen abc>:117(__instancecheck__)
#         5    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:157(_splitext)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:117(splitext)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.533    0.533 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1098(memory_info)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 __init__.py:287(compile)
#         2    0.000    0.000    0.001    0.000 __init__.py:318(__init__)
#         2    0.000    0.000    0.001    0.000 __init__.py:321(_init)
#         1    0.000    0.000    0.000    0.000 __init__.py:330(_compile)
#         4    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         1    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         2    0.000    0.000    0.000    0.000 __init__.py:450(pid)
#         5    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:599(__init__)
#     88235    0.014    0.000    0.098    0.000 __init__.py:673(update)
#         2    0.000    0.000    0.000    0.000 __init__.py:751(create_time)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         1    0.000    0.000    0.005    0.005 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.005    0.005 _base.py:537(set_result)
#       6/4    0.000    0.000    0.001    0.000 _common.py:498(wrapper)
#         2    0.000    0.000    0.002    0.001 _methods.py:101(_mean)
#         2    0.000    0.000    0.000    0.000 _methods.py:67(_count_reduce_items)
#       8/4    0.000    0.000    0.001    0.000 _psosx.py:346(wrapper)
#         2    0.000    0.000    0.000    0.000 _psosx.py:366(__init__)
#         2    0.000    0.000    0.000    0.000 _psosx.py:371(_get_kinfo_proc)
#         2    0.000    0.000    0.000    0.000 _psosx.py:379(_get_pidtaskinfo)
#         2    0.000    0.000    0.000    0.000 _psosx.py:448(memory_info)
#         2    0.000    0.000    0.000    0.000 _psosx.py:475(create_time)
#         1    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         1    0.000    0.000    0.000    0.000 ast.py:1825(__getattr__)
#         3    0.000    0.000    0.074    0.025 asyncio.py:206(_handle_events)
#         2    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#         2    0.000    0.000    0.000    0.000 asyncio.py:231(add_callback)
#        11    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#        11    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#       4/2    0.001    0.000    0.490    0.245 backends.py:525(_call_if_no_backends_installed)
#         1    0.000    0.000    0.000    0.000 base.py:1671(name)
#         1    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         7    0.000    0.000    0.000    0.000 base.py:3809(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         2    0.000    0.000    0.006    0.003 base.py:475(__new__)
#         8    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         1    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5295(_validate_fill_value)
#         1    0.002    0.002    0.003    0.003 base.py:5323(__contains__)
#         2    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         2    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         2    0.001    0.000    0.001    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:674(_with_infer)
#         1    0.000    0.000    0.002    0.002 base.py:6956(insert)
#         4    0.000    0.000    0.006    0.002 base.py:7593(ensure_index)
#         2    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 base.py:82(shape)
#         3    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         3    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         1    0.001    0.001    0.001    0.001 base.py:842(_engine)
#         5    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         2    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         3    0.000    0.000    0.000    0.000 base_events.py:1947(_add_callback)
#         7    0.000    0.000    0.293    0.042 base_events.py:1962(_run_once)
#         8    0.000    0.000    0.000    0.000 base_events.py:2060(get_debug)
#         6    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:758(is_closed)
#        13    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         2    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#         2    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#         3    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         4    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         1    0.000    0.000    0.001    0.001 base_events.py:876(call_soon_threadsafe)
#         2    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#         1    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         1    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         1    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#         2    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         1    0.001    0.001    0.005    0.005 cast.py:124(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1519(construct_1d_arraylike_from_scalar)
#         1    0.001    0.001    0.003    0.003 cast.py:1580(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 cast.py:1763(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 cast.py:775(infer_dtype_from_scalar)
#         1    0.000    0.000    0.001    0.001 classic.py:566(empty_graph)
#         1    0.103    0.103    0.206    0.206 cluster.py:19(triangles)
#         1    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         3    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         1    0.000    0.000    0.000    0.000 concurrent.py:185(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         1    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         1    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         1    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         1    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 construction.py:1006(convert_object_array)
#         2    0.000    0.000    0.000    0.000 construction.py:1028(convert)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         5    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         3    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.008    0.008 construction.py:506(nested_data_to_arrays)
#         5    0.000    0.000    0.005    0.001 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#         4    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#         4    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#         4    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         1    0.000    0.000    0.008    0.008 construction.py:793(to_arrays)
#         1    0.000    0.000    0.007    0.007 construction.py:891(_list_of_dict_to_arrays)
#        21    0.000    0.000    0.000    0.000 construction.py:915(<genexpr>)
#         1    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         1    0.000    0.000    0.000    0.000 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         1    0.000    0.000    0.001    0.001 construction.py:96(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#         1    0.000    0.000    0.000    0.000 coreviews.py:44(__init__)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1331(is_dataclass)
#         1    0.000    0.000    0.000    0.000 decorator.py:200(fix)
#         1    0.001    0.001    0.011    0.011 decorator.py:232(fun)
#         1    0.000    0.000    0.004    0.004 decorators.py:180(_open_file)
#         1    0.000    0.000    0.000    0.000 decorators.py:195(<lambda>)
#         1    0.000    0.000    0.000    0.000 decorators.py:246(_nodes_or_number)
#         1    0.000    0.000    0.000    0.000 decorators.py:83(_not_implemented_for)
#        56    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#        56    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#         1    0.001    0.001    0.003    0.003 edgelist.py:176(parse_edgelist)
#         1    0.001    0.001    0.283    0.283 edgelist.py:300(read_edgelist)
#     88235    0.021    0.000    0.033    0.000 edgelist.py:377(<genexpr>)
#         4    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         4    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         4    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        56    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         1    0.000    0.000    0.000    0.000 enum.py:1337(value)
#       120    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#        24    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#        16    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         1    0.000    0.000    0.000    0.000 enum.py:199(__get__)
#        56    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         2    0.000    0.000    0.000    0.000 events.py:113(__init__)
#         2    0.000    0.000    0.000    0.000 events.py:129(__lt__)
#         6    0.000    0.000    0.000    0.000 events.py:36(__init__)
#       8/6    0.000    0.000    0.076    0.013 events.py:87(_run)
#         1    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#         1    0.000    0.000    0.007    0.007 frame.py:4271(__setitem__)
#         1    0.000    0.000    0.003    0.003 frame.py:4481(_set_item_mgr)
#         1    0.000    0.000    0.007    0.007 frame.py:4514(_set_item)
#         1    0.001    0.001    0.001    0.001 frame.py:4585(_ensure_valid_index)
#         1    0.000    0.000    0.001    0.001 frame.py:5242(_sanitize_column)
#         1    0.002    0.002    0.011    0.011 frame.py:694(__init__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3380(_mean_dispatcher)
#         2    0.000    0.000    0.002    0.001 fromnumeric.py:3385(mean)
#         1    0.000    0.000    0.000    0.000 function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.001    0.001 function_base.py:5369(insert)
#         2    0.000    0.000    0.000    0.000 function_base.py:5559(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:5563(append)
#         2    0.000    0.000    0.000    0.000 functools.py:1010(__get__)
#         1    0.002    0.002    0.005    0.005 futures.py:391(_call_set_state)
#         1    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#        26    0.000    0.000    0.000    0.000 generic.py:37(_check)
#        26    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#         1    0.000    0.000    0.000    0.000 graph.py:1479(adjacency)
#         1    0.000    0.000    0.000    0.000 graph.py:1499(degree)
#         1    0.000    0.000    0.000    0.000 graph.py:1537(clear)
#         1    0.000    0.000    0.000    0.000 graph.py:1577(is_directed)
#         1    0.000    0.000    0.002    0.002 graph.py:1907(size)
#      4040    0.000    0.000    0.001    0.000 graph.py:1943(<genexpr>)
#         1    0.000    0.000    0.002    0.002 graph.py:1950(number_of_edges)
#         1    0.001    0.001    0.002    0.002 graph.py:339(__init__)
#         1    0.000    0.000    0.000    0.000 graph.py:38(__set__)
#         1    0.000    0.000    0.000    0.000 graph.py:382(adj)
#         1    0.000    0.000    0.000    0.000 graph.py:444(__iter__)
#         1    0.000    0.000    0.000    0.000 graph.py:573(add_nodes_from)
#         1    0.000    0.000    0.000    0.000 graph.py:63(__set__)
#         1    0.000    0.000    0.000    0.000 graph.py:838(number_of_nodes)
#     88234    0.075    0.000    0.103    0.000 graph.py:906(add_edge)
#         1    0.000    0.000    0.001    0.001 history.py:1008(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.001    0.001 history.py:1024(writeout_cache)
#         2    0.000    0.000    0.000    0.000 history.py:1065(hold)
#         1    0.002    0.002    0.010    0.010 history.py:92(only_when_enabled)
#         4    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         1    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         1    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         2    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#         2    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#         4    0.000    0.000    0.000    0.000 inspect.py:2807(name)
#        10    0.000    0.000    0.000    0.000 inspect.py:2819(kind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2901(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2909(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2932(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2962(apply_defaults)
#         4    0.000    0.000    0.000    0.000 inspect.py:3102(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:3148(_bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:3290(bind)
#        56    0.000    0.000    0.001    0.000 interactiveshell.py:3027(write)
#         4    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#         2    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#         3    0.000    0.000    0.002    0.001 ioloop.py:750(_run_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         5    0.000    0.000    0.074    0.015 iostream.py:157(_handle_event)
#         3    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         3    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.001    0.001 iostream.py:259(schedule)
#         1    0.000    0.000    0.001    0.001 iostream.py:271(send_multipart)
#         3    0.000    0.000    0.074    0.025 iostream.py:276(<lambda>)
#         3    0.000    0.000    0.068    0.023 iostream.py:278(_really_send)
#        56    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#        56    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#        56    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         1    0.000    0.000    0.002    0.002 iostream.py:616(_flush)
#        56    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#       102    0.001    0.000    0.001    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.005    0.005 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.002    0.002 managers.py:1347(insert)
#         3    0.000    0.000    0.000    0.000 managers.py:1392(<genexpr>)
#         1    0.000    0.000    0.000    0.000 managers.py:1402(_insert_update_mgr_locs)
#         1    0.000    0.000    0.000    0.000 managers.py:1412(_insert_update_blklocs_and_blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1764(is_consolidated)
#         1    0.000    0.000    0.000    0.000 managers.py:1772(_consolidate_check)
#         1    0.000    0.000    0.000    0.000 managers.py:1782(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         1    0.000    0.000    0.001    0.001 managers.py:2121(create_block_manager_from_column_arrays)
#         2    0.000    0.000    0.000    0.000 managers.py:2177(_grouping_func)
#         1    0.000    0.000    0.000    0.000 managers.py:2190(_form_blocks)
#         1    0.000    0.000    0.000    0.000 managers.py:2246(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:2311(_fast_count_smallints)
#         1    0.000    0.000    0.000    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#     88236    0.009    0.000    0.014    0.000 misc.py:593(_clear_cache)
#         1    0.000    0.000    0.001    0.001 missing.py:101(isna)
#         1    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         1    0.000    0.000    0.001    0.001 missing.py:728(is_valid_na_for_dtype)
#         6    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#         2    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#         1    0.000    0.000    0.000    0.000 multiarray.py:892(bincount)
#         2    0.000    0.000    0.000    0.000 numeric.py:1330(normalize_axis_tuple)
#         1    0.000    0.000    0.000    0.000 numeric.py:1389(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:1393(moveaxis)
#         6    0.001    0.000    0.001    0.000 numeric.py:274(full)
#         6    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         6    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         6    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:421(__init__)
#         3    0.000    0.000    0.000    0.000 reportviews.py:428(__call__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:468(__len__)
#     12120    0.002    0.000    0.003    0.000 reportviews.py:531(__iter__)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.001    0.001 selector_events.py:141(_write_to_self)
#         7    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#       6/1    0.074    0.012    0.000    0.000 selectors.py:540(select)
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:649(msg)
#         1    0.000    0.000    0.000    0.000 session.py:675(sign)
#         1    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         1    0.000    0.000    0.002    0.002 session.py:754(send)
#         4    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#        23    0.000    0.000    0.000    0.000 socket.py:623(send)
#         3    0.026    0.009    0.068    0.023 socket.py:700(send_multipart)
#         5    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#       408    0.000    0.000    0.000    0.000 threading.py:1112(ident)
#         2    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         2    0.000    0.000    0.000    0.000 threading.py:122(RLock)
#        51    0.000    0.000    0.000    0.000 threading.py:1479(enumerate)
#         3    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         1    0.000    0.000    0.000    0.000 threading.py:398(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:428(notify_all)
#         2    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:631(clear)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#       131    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#       131    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         3    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         3    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         5    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#        10    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         5    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#       288    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#        15    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 unix_events.py:83(_process_self_data)
#         1    0.000    0.000    0.000    0.000 warnings.py:131(filterwarnings)
#         1    0.000    0.000    0.000    0.000 warnings.py:188(_add_filter)
#         2    0.000    0.000    0.000    0.000 warnings.py:462(__init__)
#         2    0.000    0.000    0.000    0.000 warnings.py:488(__enter__)
#         2    0.000    0.000    0.000    0.000 warnings.py:509(__exit__)
#        11    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         5    0.000    0.000    0.074    0.015 zmqstream.py:546(_run_callback)
#         5    0.000    0.000    0.075    0.015 zmqstream.py:573(_handle_events)
#         5    0.000    0.000    0.074    0.015 zmqstream.py:614(_handle_recv)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:653(_rebuild_io_state)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:676(_update_handler)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#         6    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10330fcf0}
#     88242    0.007    0.000    0.007    0.000 {built-in method _abc._abc_instancecheck}
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#     88234    0.060    0.000    0.060    0.000 {built-in method _collections._count_elements}
#         5    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         2    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.004    0.004    0.004    0.004 {built-in method _io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#     88290    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 177066/177056    0.015    0.000    0.030    0.000 {built-in method builtins.isinstance}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 276974/276963    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        28    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         2    0.001    0.000    0.001    0.001 {built-in method builtins.sorted}
#         4    0.000    0.000    0.002    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        10    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        64    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.check_pid_range}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_kinfo_oneshot}
#         2    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_pidtaskinfo_oneshot}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#        13    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         6    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       109    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        10    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.001    0.000    0.001    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        13    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        17    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#       6/1    0.000    0.000    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#     88234    0.007    0.000    0.007    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     88234    0.006    0.000    0.006    0.000 {method 'find' of 'str' objects}
#        56    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#     88246    0.007    0.000    0.007    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        60    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       224    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#    176468    0.014    0.000    0.014    0.000 {method 'pop' of 'list' objects}
#        15    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         2    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#     88234    0.007    0.000    0.007    0.000 {method 'rstrip' of 'str' objects}
#       8/6    0.000    0.000    0.076    0.013 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#     88235    0.008    0.000    0.008    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#     88236    0.007    0.000    0.007    0.000 {method 'update' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       104    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        56    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# ### Main function and combined output
#
# - Combined output is saved into two .CSV files

# %%
def main():
    file_path = "data/facebook_combined.txt"
    
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found. Please download from http://snap.stanford.edu/data/egnets-Facebook.html")
        return
    
    num_runs = 1
    

    cProfile.run(f'profile_wrapper("{file_path}", {num_runs})')

    # Run the function again to capture return values for further processing
    results, top_nodes_dfs = profile_wrapper(file_path, num_runs)

    # Combine results
    print("\nTable: Performance Comparison (Averaged over runs)")
    df = pd.DataFrame(results)
    print(df.round(6))
    df.to_csv("01-01-graph_analysis_comparison.csv", index=False)
    print("\nResults saved to 01-01-graph_analysis_comparison.csv")
    
    # Save top nodes to CSV
    top_nodes_combined = pd.concat(top_nodes_dfs, ignore_index=True)
    top_nodes_combined.to_csv("01-01-top_20_nodes.csv", index=False)
    print("Top 20 nodes saved to 01-01-top_20_nodes.csv")

if __name__ == "__main__":
    main()
# Out:
# Running Naive analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.25 seconds
# Memory Used: 14.73 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#
# Running NetworkX analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.44 seconds
# Memory Used: 9.34 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#
# Running SciPy Sparse analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.21 seconds
# Memory Used: 91.86 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#          2366564 function calls (2366459 primitive calls) in 1.042 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.003    0.001    0.718    0.239 2161703591.py:2(run_analysis_with_repeats)
#         1    0.000    0.000    0.210    0.210 2161703591.py:27(run_all_analyses)
#         1    0.000    0.000    1.041    1.041 2161703591.py:46(profile_wrapper)
#      4039    0.000    0.000    0.000    0.000 2575337673.py:117(<lambda>)
#         1    0.000    0.000    0.208    0.208 2575337673.py:147(analyze_scipy_sparse)
#        20    0.000    0.000    0.000    0.000 2575337673.py:193(<lambda>)
#         1    0.000    0.000    0.033    0.033 2575337673.py:2(analyze_naive)
#      4040    0.000    0.000    0.000    0.000 2575337673.py:37(<genexpr>)
#      4040    0.000    0.000    0.000    0.000 2575337673.py:52(<genexpr>)
#      4039    0.000    0.000    0.001    0.000 2575337673.py:56(<lambda>)
#         1    0.000    0.000    0.440    0.440 2575337673.py:89(analyze_networkx)
#         6    0.000    0.000    0.001    0.000 3910727439.py:2(get_memory_usage)
#         1    0.000    0.000    0.238    0.238 <class 'networkx.utils.decorators.argmap'> compilation 10:1(argmap_parse_edgelist_7)
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 14:1(argmap_empty_graph_11)
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 18:1(argmap_empty_graph_15)
#         1    0.000    0.000    0.192    0.192 <class 'networkx.utils.decorators.argmap'> compilation 23:1(argmap_triangles_19)
#         1    0.000    0.000    0.000    0.000 <class 'networkx.utils.decorators.argmap'> compilation 6:1(argmap_read_edgelist_1)
#     88283    0.007    0.000    0.014    0.000 <frozen abc>:117(__instancecheck__)
#         6    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:263(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen codecs>:312(__init__)
#       112    0.000    0.000    0.000    0.000 <frozen codecs>:322(decode)
#         6    0.000    0.000    0.000    0.000 <frozen codecs>:334(getstate)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:157(_splitext)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:645(parent)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:117(splitext)
#         3    0.000    0.000    0.000    0.000 <frozen posixpath>:229(expanduser)
#         6    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    1.041    1.041 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         6    0.000    0.000    0.000    0.000 __init__.py:1098(memory_info)
#        12    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         3    0.000    0.000    0.000    0.000 __init__.py:287(compile)
#         6    0.000    0.000    0.001    0.000 __init__.py:318(__init__)
#         6    0.000    0.000    0.001    0.000 __init__.py:321(_init)
#         3    0.000    0.000    0.000    0.000 __init__.py:330(_compile)
#        15    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#         3    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         6    0.000    0.000    0.000    0.000 __init__.py:450(pid)
#        15    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:599(__init__)
#     88235    0.014    0.000    0.096    0.000 __init__.py:673(update)
#         6    0.000    0.000    0.000    0.000 __init__.py:751(create_time)
#         5    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         6    0.000    0.000    0.000    0.000 _base.py:114(__init__)
#         9    0.000    0.000    0.000    0.000 _base.py:1356(_get_index_dtype)
#         7    0.000    0.000    0.000    0.000 _base.py:1388(issparse)
#         1    0.000    0.000    0.000    0.000 _base.py:230(_ascontainer)
#        27    0.000    0.000    0.000    0.000 _base.py:341(nnz)
#        13    0.000    0.000    0.000    0.000 _base.py:361(format)
#         2    0.000    0.000    0.000    0.000 _base.py:428(asformat)
#         2    0.000    0.000    0.027    0.013 _base.py:597(_matmul_dispatch)
#        11    0.000    0.000    0.000    0.000 _base.py:70(ndim)
#         2    0.000    0.000    0.189    0.095 _base.py:728(__matmul__)
#        17    0.000    0.000    0.000    0.000 _base.py:74(_shape_as_2d)
#     18/12    0.000    0.000    0.000    0.000 _common.py:498(wrapper)
#        25    0.000    0.000    0.000    0.000 _compressed.py:117(_getnnz)
#         1    0.000    0.000    0.000    0.000 _compressed.py:1196(has_canonical_format)
#         2    0.000    0.000    0.000    0.000 _compressed.py:1219(has_canonical_format)
#         1    0.000    0.000    0.002    0.002 _compressed.py:1225(sum_duplicates)
#         1    0.000    0.000    0.000    0.000 _compressed.py:1240(has_sorted_indices)
#         2    0.000    0.000    0.000    0.000 _compressed.py:1256(has_sorted_indices)
#         1    0.000    0.000    0.002    0.002 _compressed.py:1272(sort_indices)
#         6    0.000    0.000    0.000    0.000 _compressed.py:1281(prune)
#         5    0.000    0.000    0.000    0.000 _compressed.py:165(check_format)
#         5    0.000    0.000    0.003    0.001 _compressed.py:29(__init__)
#         2    0.000    0.000    0.026    0.013 _compressed.py:546(_matmul_sparse)
#         1    0.000    0.000    0.004    0.004 _compressed.py:606(diagonal)
#         1    0.000    0.000    0.001    0.001 _compressed.py:662(sum)
#         1    0.000    0.000    0.000    0.000 _compressed.py:687(_minor_reduce)
#         2    0.000    0.000    0.000    0.000 _coo.py:165(_getnnz)
#         6    0.000    0.000    0.000    0.000 _coo.py:168(<genexpr>)
#         6    0.000    0.000    0.000    0.000 _coo.py:172(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _coo.py:202(_check)
#         3    0.000    0.000    0.000    0.000 _coo.py:215(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _coo.py:30(__init__)
#         1    0.000    0.000    0.001    0.001 _coo.py:381(_coo_to_compressed)
#         3    0.000    0.000    0.000    0.000 _coo.py:60(<genexpr>)
#        17    0.000    0.000    0.000    0.000 _csr.py:127(_swap)
#         6    0.000    0.000    0.000    0.000 _data.py:21(__init__)
#         7    0.000    0.000    0.000    0.000 _data.py:24(dtype)
#         1    0.000    0.000    0.000    0.000 _matrix.py:13(_coo_container)
#        12    0.000    0.000    0.000    0.000 _matrix.py:65(get_shape)
#         1    0.000    0.000    0.000    0.000 _methods.py:101(_mean)
#         4    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_amin)
#         2    0.000    0.000    0.000    0.000 _methods.py:47(_sum)
#         1    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         1    0.001    0.001    0.001    0.001 _methods.py:61(_all)
#         1    0.000    0.000    0.000    0.000 _methods.py:67(_count_reduce_items)
#     24/12    0.000    0.000    0.000    0.000 _psosx.py:346(wrapper)
#         6    0.000    0.000    0.000    0.000 _psosx.py:366(__init__)
#         6    0.000    0.000    0.000    0.000 _psosx.py:371(_get_kinfo_proc)
#         6    0.000    0.000    0.000    0.000 _psosx.py:379(_get_pidtaskinfo)
#         6    0.000    0.000    0.000    0.000 _psosx.py:448(memory_info)
#         6    0.000    0.000    0.000    0.000 _psosx.py:475(create_time)
#         1    0.000    0.000    0.000    0.000 _sputils.py:112(getdtype)
#         1    0.000    0.000    0.000    0.000 _sputils.py:142(getdata)
#         3    0.000    0.000    0.000    0.000 _sputils.py:25(upcast)
#         9    0.000    0.000    0.000    0.000 _sputils.py:264(get_index_dtype)
#         1    0.000    0.000    0.000    0.000 _sputils.py:336(get_sum_dtype)
#         4    0.000    0.000    0.000    0.000 _sputils.py:345(isscalarlike)
#         2    0.000    0.000    0.000    0.000 _sputils.py:350(isintlike)
#         4    0.000    0.000    0.000    0.000 _sputils.py:372(isshape)
#         4    0.000    0.000    0.000    0.000 _sputils.py:402(isdense)
#         4    0.000    0.000    0.000    0.000 _sputils.py:429(check_shape)
#        12    0.000    0.000    0.000    0.000 _sputils.py:457(<genexpr>)
#        12    0.000    0.000    0.000    0.000 _sputils.py:462(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _sputils.py:584(asmatrix)
#         1    0.000    0.000    0.000    0.000 _sputils.py:76(downcast_intp_index)
#         1    0.000    0.000    0.000    0.000 _sputils.py:96(to_native)
#        12    0.000    0.000    0.000    0.000 _util.py:229(_prune_array)
#         1    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#         3    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         1    0.000    0.000    0.000    0.000 arraysetops.py:125(_unpack_tuple)
#         1    0.000    0.000    0.000    0.000 arraysetops.py:133(_unique_dispatcher)
#         1    0.000    0.000    0.004    0.004 arraysetops.py:138(unique)
#         1    0.000    0.000    0.004    0.004 arraysetops.py:323(_unique1d)
#         1    0.000    0.000    0.000    0.000 ast.py:1825(__getattr__)
#         5    0.000    0.000    0.077    0.015 asyncio.py:206(_handle_events)
#         3    0.000    0.000    0.000    0.000 asyncio.py:216(call_at)
#         1    0.001    0.001    0.001    0.001 asyncio.py:231(add_callback)
#        12    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#        12    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#       4/2    0.001    0.000    0.430    0.215 backends.py:525(_call_if_no_backends_installed)
#         5    0.000    0.000    0.000    0.000 base.py:1671(name)
#         3    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         3    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#        21    0.000    0.000    0.000    0.000 base.py:3809(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         9    0.000    0.000    0.002    0.000 base.py:475(__new__)
#        27    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         3    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         3    0.000    0.000    0.000    0.000 base.py:5295(_validate_fill_value)
#         3    0.002    0.001    0.002    0.001 base.py:5323(__contains__)
#         1    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#         3    0.000    0.000    0.000    0.000 base.py:549(find)
#         1    0.000    0.000    0.001    0.001 base.py:5552(equals)
#         1    0.000    0.000    0.001    0.001 base.py:5651(identical)
#         2    0.000    0.000    0.000    0.000 base.py:5676(<genexpr>)
#         9    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         9    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         9    0.001    0.000    0.001    0.000 base.py:649(_simple_new)
#         3    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:674(_with_infer)
#         3    0.000    0.000    0.000    0.000 base.py:6956(insert)
#         1    0.000    0.000    0.000    0.000 base.py:74(__len__)
#        22    0.000    0.000    0.005    0.000 base.py:7593(ensure_index)
#        13    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 base.py:791(is_)
#         3    0.000    0.000    0.000    0.000 base.py:82(shape)
#        13    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         4    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         9    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         3    0.001    0.000    0.001    0.000 base.py:842(_engine)
#         3    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#        29    0.000    0.000    0.000    0.000 base.py:909(__len__)
#         8    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         5    0.000    0.000    0.000    0.000 base_events.py:1947(_add_callback)
#         8    0.000    0.000    1.317    0.165 base_events.py:1962(_run_once)
#         4    0.000    0.000    0.000    0.000 base_events.py:2060(get_debug)
#         4    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#        20    0.000    0.000    0.000    0.000 base_events.py:772(time)
#         3    0.000    0.000    0.000    0.000 base_events.py:781(call_later)
#         3    0.000    0.000    0.000    0.000 base_events.py:805(call_at)
#         1    0.000    0.000    0.000    0.000 base_events.py:823(call_soon)
#         1    0.000    0.000    0.000    0.000 base_events.py:852(_call_soon)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1123(_make_date_converter)
#         1    0.000    0.000    0.000    0.000 base_parser.py:115(__init__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1269(_process_date_conversion)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1426(_validate_parse_dates_arg)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1447(is_index_col)
#         1    0.000    0.000    0.000    0.000 base_parser.py:191(_validate_parse_dates_presence)
#         1    0.000    0.000    0.000    0.000 base_parser.py:255(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 base_parser.py:350(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:362(_make_index)
#         1    0.000    0.000    0.000    0.000 base_parser.py:601(_set_noconvert_dtype_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:871(_do_date_conversions)
#         1    0.000    0.000    0.000    0.000 base_parser.py:893(_check_data_length)
#         1    0.000    0.000    0.000    0.000 base_parser.py:986(_validate_usecols_arg)
#         8    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#         2    0.000    0.000    0.000    0.000 blocks.py:219(_can_consolidate)
#         5    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#        10    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         3    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         2    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         1    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#         3    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#         2    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:790(copy)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:194(close)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:201(_set_noconvert_columns)
#         1    0.003    0.003    0.004    0.004 c_parser_wrapper.py:222(read)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:355(_concatenate_chunks)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:392(ensure_dtype_objs)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:60(__init__)
#         6    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         6    0.000    0.000    0.001    0.000 cast.py:124(maybe_convert_platform)
#         3    0.000    0.000    0.000    0.000 cast.py:1519(construct_1d_arraylike_from_scalar)
#         7    0.001    0.000    0.002    0.000 cast.py:1580(construct_1d_object_array_from_listlike)
#         3    0.000    0.000    0.000    0.000 cast.py:1763(np_can_hold_element)
#         3    0.000    0.000    0.000    0.000 cast.py:775(infer_dtype_from_scalar)
#         1    0.000    0.000    0.000    0.000 classic.py:566(empty_graph)
#         1    0.068    0.068    0.191    0.191 cluster.py:19(triangles)
#         3    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         3    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1117(_maybe_memory_map)
#         2    0.000    0.000    0.000    0.000 common.py:1165(_is_binary_mode)
#         2    0.000    0.000    0.000    0.000 common.py:1204(is_potential_multi_index)
#         1    0.000    0.000    0.000    0.000 common.py:121(classes)
#         2    0.000    0.000    0.000    0.000 common.py:1229(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:1233(dedup_names)
#         3    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#        11    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:131(close)
#        18    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#         3    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#         6    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#         4    0.000    0.000    0.000    0.000 common.py:1596(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:160(is_url)
#         3    0.000    0.000    0.000    0.000 common.py:188(_expand_user)
#         1    0.000    0.000    0.000    0.000 common.py:188(all_none)
#         1    0.000    0.000    0.000    0.000 common.py:192(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:207(validate_header_arg)
#         3    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         2    0.000    0.000    0.000    0.000 common.py:248(stringify_path)
#         1    0.000    0.000    0.000    0.000 common.py:292(is_fsspec_url)
#         1    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#         1    0.000    0.000    0.000    0.000 common.py:304(_get_filepath_or_buffer)
#         3    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 common.py:515(get_compression_method)
#         1    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:550(infer_compression)
#        10    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         1    0.000    0.000    0.000    0.000 common.py:664(get_handle)
#         2    0.000    0.000    0.000    0.000 common.py:91(ensure_python_int)
#         2    0.000    0.000    0.000    0.000 concat.py:52(concat_compat)
#         6    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         6    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         6    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         6    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         6    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         6    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         3    0.000    0.000    0.001    0.000 construction.py:1006(convert_object_array)
#         6    0.001    0.000    0.001    0.000 construction.py:1028(convert)
#         4    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#        22    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         1    0.000    0.000    0.001    0.001 construction.py:423(dict_to_mgr)
#        14    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         3    0.000    0.000    0.006    0.002 construction.py:506(nested_data_to_arrays)
#        22    0.000    0.000    0.001    0.000 construction.py:517(sanitize_array)
#         3    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         4    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         7    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#        19    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#        19    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#        19    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 construction.py:769(_try_cast)
#         3    0.000    0.000    0.006    0.002 construction.py:793(to_arrays)
#         3    0.000    0.000    0.005    0.002 construction.py:891(_list_of_dict_to_arrays)
#        63    0.000    0.000    0.000    0.000 construction.py:915(<genexpr>)
#         3    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         3    0.000    0.000    0.001    0.000 construction.py:928(_finalize_columns_and_data)
#         3    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         4    0.000    0.000    0.000    0.000 construction.py:96(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 copy.py:103(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 copy.py:62(copy)
#         1    0.000    0.000    0.000    0.000 coreviews.py:44(__init__)
#         3    0.000    0.000    0.000    0.000 dataclasses.py:1331(is_dataclass)
#         1    0.000    0.000    0.000    0.000 decorators.py:180(_open_file)
#         1    0.000    0.000    0.000    0.000 decorators.py:195(<lambda>)
#         1    0.000    0.000    0.000    0.000 decorators.py:246(_nodes_or_number)
#         1    0.000    0.000    0.000    0.000 decorators.py:83(_not_implemented_for)
#       4/3    0.000    0.000    0.000    0.000 defmatrix.py:168(__array_finalize__)
#         1    0.000    0.000    0.000    0.000 defmatrix.py:254(_collapse)
#         1    0.000    0.000    0.000    0.000 defmatrix.py:288(sum)
#         1    0.000    0.000    0.000    0.000 defmatrix.py:936(T)
#       174    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#       174    0.000    0.000    0.000    0.000 displaypub.py:150(is_publishing)
#         1    0.087    0.087    0.238    0.238 edgelist.py:176(parse_edgelist)
#         1    0.000    0.000    0.238    0.238 edgelist.py:300(read_edgelist)
#     88235    0.019    0.000    0.031    0.000 edgelist.py:377(<genexpr>)
#        12    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#        12    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#        12    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        60    0.000    0.000    0.000    0.000 enum.py:1156(__new__)
#         4    0.000    0.000    0.000    0.000 enum.py:1337(value)
#       126    0.000    0.000    0.000    0.000 enum.py:1589(_get_value)
#        24    0.000    0.000    0.000    0.000 enum.py:1596(__or__)
#        18    0.000    0.000    0.000    0.000 enum.py:1607(__and__)
#         4    0.000    0.000    0.000    0.000 enum.py:199(__get__)
#        60    0.000    0.000    0.000    0.000 enum.py:695(__call__)
#         3    0.000    0.000    0.000    0.000 events.py:113(__init__)
#         3    0.000    0.000    0.000    0.000 events.py:129(__lt__)
#         4    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         9    0.000    0.000    0.090    0.010 events.py:87(_run)
#         8    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#         2    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#        18    0.000    0.000    0.000    0.000 fractions.py:203(__new__)
#        12    0.000    0.000    0.000    0.000 fractions.py:334(_from_coprime_ints)
#         6    0.000    0.000    0.000    0.000 fractions.py:414(numerator)
#         6    0.000    0.000    0.000    0.000 fractions.py:418(denominator)
#         6    0.000    0.000    0.000    0.000 fractions.py:663(forward)
#         6    0.000    0.000    0.000    0.000 fractions.py:677(reverse)
#         6    0.000    0.000    0.000    0.000 fractions.py:760(_add)
#         6    0.000    0.000    0.000    0.000 fractions.py:808(_div)
#         3    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#         1    0.000    0.000    0.000    0.000 frame.py:1933(to_numpy)
#         3    0.000    0.000    0.004    0.001 frame.py:4271(__setitem__)
#         3    0.000    0.000    0.001    0.000 frame.py:4481(_set_item_mgr)
#         3    0.000    0.000    0.004    0.001 frame.py:4514(_set_item)
#         3    0.000    0.000    0.000    0.000 frame.py:4585(_ensure_valid_index)
#         3    0.000    0.000    0.000    0.000 frame.py:5242(_sanitize_column)
#         4    0.001    0.000    0.008    0.002 frame.py:694(__init__)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1881(nonzero)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2508(_cumsum_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2512(cumsum)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3172(_ndim_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3176(ndim)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:53(_wrapfunc)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:775(_argpartition_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:779(argpartition)
#         1    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 function_base.py:1320(_diff_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:1324(diff)
#         3    0.000    0.000    0.000    0.000 function_base.py:5365(_insert_dispatcher)
#         3    0.000    0.000    0.000    0.000 function_base.py:5369(insert)
#         6    0.000    0.000    0.000    0.000 function_base.py:5559(_append_dispatcher)
#         6    0.000    0.000    0.000    0.000 function_base.py:5563(append)
#         2    0.000    0.000    0.000    0.000 functools.py:1010(__get__)
#         8    0.000    0.000    0.000    0.000 generic.py:278(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#         2    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#       126    0.000    0.000    0.000    0.000 generic.py:37(_check)
#         4    0.000    0.000    0.000    0.000 generic.py:405(flags)
#       126    0.000    0.000    0.000    0.000 generic.py:42(_instancecheck)
#         3    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 generic.py:511(_validate_dtype)
#         1    0.000    0.000    0.001    0.001 generic.py:5343(reindex)
#         2    0.000    0.000    0.001    0.000 generic.py:5598(<genexpr>)
#         2    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 generic.py:586(_get_axis)
#         2    0.000    0.000    0.000    0.000 generic.py:6236(__finalize__)
#         3    0.000    0.000    0.000    0.000 generic.py:6284(__getattr__)
#         4    0.000    0.000    0.000    0.000 generic.py:6301(__setattr__)
#         1    0.000    0.000    0.000    0.000 generic.py:6662(copy)
#         6    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#         3    0.000    0.000    0.000    0.000 generic.py:807(_set_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:8693(isna)
#        18    0.000    0.000    0.000    0.000 getlimits.py:685(__init__)
#         9    0.000    0.000    0.000    0.000 getlimits.py:696(min)
#         9    0.000    0.000    0.000    0.000 getlimits.py:709(max)
#         1    0.000    0.000    0.000    0.000 graph.py:1479(adjacency)
#         1    0.000    0.000    0.000    0.000 graph.py:1499(degree)
#         1    0.000    0.000    0.000    0.000 graph.py:1537(clear)
#         1    0.000    0.000    0.000    0.000 graph.py:1577(is_directed)
#         1    0.000    0.000    0.001    0.001 graph.py:1907(size)
#      4040    0.000    0.000    0.001    0.000 graph.py:1943(<genexpr>)
#         1    0.000    0.000    0.001    0.001 graph.py:1950(number_of_edges)
#         1    0.000    0.000    0.000    0.000 graph.py:339(__init__)
#         1    0.000    0.000    0.000    0.000 graph.py:38(__set__)
#         1    0.000    0.000    0.000    0.000 graph.py:382(adj)
#         1    0.000    0.000    0.000    0.000 graph.py:444(__iter__)
#         1    0.000    0.000    0.000    0.000 graph.py:573(add_nodes_from)
#         1    0.000    0.000    0.000    0.000 graph.py:63(__set__)
#         1    0.000    0.000    0.000    0.000 graph.py:838(number_of_nodes)
#     88234    0.052    0.000    0.078    0.000 graph.py:906(add_edge)
#         1    0.000    0.000    0.000    0.000 history.py:1016(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 history.py:1065(hold)
#        12    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         3    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         3    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         3    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         2    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#         4    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         7    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         3    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#        19    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         3    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#       174    0.000    0.000    0.033    0.000 interactiveshell.py:3027(write)
#         1    0.000    0.000    0.005    0.005 interactiveshell.py:318(_modified_open)
#         6    0.000    0.000    0.000    0.000 ioloop.py:549(time)
#         3    0.000    0.000    0.000    0.000 ioloop.py:604(call_later)
#         4    0.000    0.000    0.013    0.003 ioloop.py:750(_run_callback)
#         7    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         6    0.000    0.000    0.044    0.007 iostream.py:157(_handle_event)
#         3    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         3    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         7    0.000    0.000    0.011    0.002 iostream.py:259(schedule)
#         3    0.000    0.000    0.011    0.004 iostream.py:271(send_multipart)
#         3    0.016    0.005    0.032    0.011 iostream.py:276(<lambda>)
#         3    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#       174    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#       174    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#       174    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         3    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         3    0.000    0.000    0.013    0.004 iostream.py:616(_flush)
#       174    0.000    0.000    0.033    0.000 iostream.py:655(write)
#         6    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         3    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         3    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#       116    0.000    0.000    0.000    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         6    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         6    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         3    0.000    0.000    0.001    0.000 managers.py:1347(insert)
#        10    0.000    0.000    0.000    0.000 managers.py:1392(<genexpr>)
#         3    0.000    0.000    0.000    0.000 managers.py:1402(_insert_update_mgr_locs)
#         3    0.000    0.000    0.000    0.000 managers.py:1412(_insert_update_blklocs_and_blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1633(as_array)
#         4    0.000    0.000    0.000    0.000 managers.py:1764(is_consolidated)
#         4    0.000    0.000    0.000    0.000 managers.py:1772(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 managers.py:1782(_consolidate_inplace)
#         3    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#         1    0.000    0.000    0.000    0.000 managers.py:1828(ndim)
#         3    0.000    0.000    0.000    0.000 managers.py:1837(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1850(from_blocks)
#         2    0.000    0.000    0.000    0.000 managers.py:1863(from_array)
#         2    0.000    0.000    0.000    0.000 managers.py:1940(_block)
#         3    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#         5    0.000    0.000    0.000    0.000 managers.py:2004(internal_values)
#         4    0.000    0.000    0.000    0.000 managers.py:2121(create_block_manager_from_column_arrays)
#         8    0.000    0.000    0.000    0.000 managers.py:2177(_grouping_func)
#         4    0.000    0.000    0.000    0.000 managers.py:2190(_form_blocks)
#         5    0.000    0.000    0.000    0.000 managers.py:2246(_stack_arrays)
#         3    0.000    0.000    0.000    0.000 managers.py:2311(_fast_count_smallints)
#         3    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:241(is_single_block)
#         4    0.000    0.000    0.000    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 managers.py:317(apply)
#         1    0.000    0.000    0.000    0.000 managers.py:557(copy)
#         4    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#     88236    0.009    0.000    0.013    0.000 misc.py:593(_clear_cache)
#         4    0.000    0.000    0.000    0.000 missing.py:101(isna)
#         1    0.000    0.000    0.000    0.000 missing.py:1073(clean_reindex_fill_method)
#         4    0.000    0.000    0.000    0.000 missing.py:184(_isna)
#         1    0.000    0.000    0.000    0.000 missing.py:261(_isna_array)
#         1    0.000    0.000    0.000    0.000 missing.py:305(_isna_string_dtype)
#         1    0.000    0.000    0.001    0.001 missing.py:466(array_equivalent)
#         3    0.000    0.000    0.000    0.000 missing.py:728(is_valid_na_for_dtype)
#        22    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#        10    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#        27    0.000    0.000    0.000    0.000 multiarray.py:503(can_cast)
#         2    0.000    0.000    0.000    0.000 multiarray.py:85(empty_like)
#         3    0.000    0.000    0.000    0.000 multiarray.py:892(bincount)
#         1    0.000    0.000    0.000    0.000 nanops.py:482(nanany)
#         6    0.000    0.000    0.000    0.000 numbers.py:308(__float__)
#         6    0.000    0.000    0.000    0.000 numeric.py:1330(normalize_axis_tuple)
#         1    0.000    0.000    0.000    0.000 numeric.py:136(ones)
#         3    0.000    0.000    0.000    0.000 numeric.py:1389(_moveaxis_dispatcher)
#         3    0.000    0.000    0.000    0.000 numeric.py:1393(moveaxis)
#         4    0.000    0.000    0.000    0.000 numeric.py:1855(isscalar)
#         1    0.000    0.000    0.000    0.000 numeric.py:2374(_array_equal_dispatcher)
#         1    0.000    0.000    0.001    0.001 numeric.py:2378(array_equal)
#        21    0.000    0.000    0.000    0.000 numeric.py:274(full)
#         1    0.000    0.000    0.000    0.000 numeric.py:611(_flatnonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 numeric.py:615(flatnonzero)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:283(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:357(issubdtype)
#         1    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         1    0.000    0.000    0.000    0.000 parse.py:119(_coerce_args)
#         1    0.000    0.000    0.000    0.000 parse.py:374(urlparse)
#         6    0.000    0.000    0.000    0.000 queue.py:115(empty)
#         6    0.000    0.000    0.000    0.000 queue.py:267(_qsize)
#         1    0.000    0.000    0.000    0.000 range.py:137(__new__)
#         4    0.000    0.000    0.000    0.000 range.py:201(_simple_new)
#         1    0.000    0.000    0.000    0.000 range.py:216(_validate_dtype)
#        20    0.000    0.000    0.000    0.000 range.py:999(__len__)
#         1    0.000    0.000    0.000    0.000 readers.py:1575(__init__)
#         1    0.000    0.000    0.000    0.000 readers.py:1622(close)
#         1    0.000    0.000    0.000    0.000 readers.py:1627(_get_options_with_defaults)
#         1    0.000    0.000    0.000    0.000 readers.py:1674(_check_file_or_buffer)
#         1    0.000    0.000    0.000    0.000 readers.py:1685(_clean_options)
#         1    0.000    0.000    0.000    0.000 readers.py:1848(_make_engine)
#         1    0.000    0.000    0.005    0.005 readers.py:1907(read)
#         1    0.000    0.000    0.000    0.000 readers.py:1987(__enter__)
#         1    0.000    0.000    0.000    0.000 readers.py:1990(__exit__)
#         1    0.000    0.000    0.000    0.000 readers.py:2056(_clean_na_values)
#         1    0.000    0.000    0.000    0.000 readers.py:2133(_refine_defaults_read)
#         1    0.000    0.000    0.000    0.000 readers.py:2267(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 readers.py:2365(_validate_skipfooter)
#         2    0.000    0.000    0.000    0.000 readers.py:527(validate_integer)
#         1    0.000    0.000    0.000    0.000 readers.py:559(_validate_names)
#         1    0.000    0.000    0.006    0.006 readers.py:583(_read)
#         1    0.000    0.000    0.006    0.006 readers.py:868(read_csv)
#         1    0.000    0.000    0.000    0.000 reportviews.py:421(__init__)
#         3    0.000    0.000    0.000    0.000 reportviews.py:428(__call__)
#         1    0.000    0.000    0.000    0.000 reportviews.py:468(__len__)
#     12120    0.002    0.000    0.002    0.000 reportviews.py:531(__iter__)
#         9    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         8    0.074    0.009    0.471    0.059 selectors.py:540(select)
#         4    0.000    0.000    0.000    0.000 series.py:1480(_clear_item_cache)
#       3/2    0.000    0.000    0.001    0.001 series.py:389(__init__)
#         1    0.000    0.000    0.001    0.001 series.py:5136(reindex)
#         1    0.000    0.000    0.000    0.000 series.py:5773(isna)
#         1    0.000    0.000    0.001    0.001 series.py:607(_init_dict)
#         1    0.000    0.000    0.000    0.000 series.py:6418(_reduce)
#         1    0.000    0.000    0.000    0.000 series.py:6459(any)
#         1    0.000    0.000    0.000    0.000 series.py:660(_constructor)
#         1    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#         4    0.000    0.000    0.000    0.000 series.py:734(name)
#         3    0.000    0.000    0.000    0.000 series.py:784(name)
#         5    0.000    0.000    0.000    0.000 series.py:831(_values)
#         1    0.000    0.000    0.000    0.000 series.py:914(__len__)
#         3    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         3    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         3    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         3    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         3    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         3    0.000    0.000    0.000    0.000 session.py:649(msg)
#         3    0.000    0.000    0.000    0.000 session.py:675(sign)
#         3    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         3    0.000    0.000    0.013    0.004 session.py:754(send)
#        12    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#     28/26    0.043    0.002    0.048    0.002 socket.py:623(send)
#         3    0.000    0.000    0.000    0.000 socket.py:700(send_multipart)
#         6    0.000    0.000    0.000    0.000 socket.py:771(recv_multipart)
#         6    0.000    0.000    0.000    0.000 statistics.py:158(_sum)
#        12    0.000    0.000    0.000    0.000 statistics.py:207(<genexpr>)
#         6    0.000    0.000    0.000    0.000 statistics.py:260(_coerce)
#         6    0.000    0.000    0.000    0.000 statistics.py:291(_exact_ratio)
#         6    0.000    0.000    0.000    0.000 statistics.py:337(_convert)
#         6    0.000    0.000    0.000    0.000 statistics.py:472(mean)
#       464    0.000    0.000    0.000    0.000 threading.py:1112(ident)
#         7    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         6    0.000    0.000    0.000    0.000 threading.py:122(RLock)
#        58    0.000    0.000    0.000    0.000 threading.py:1479(enumerate)
#         1    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#         1    0.000    0.000    0.000    0.000 threading.py:312(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:318(_is_owned)
#         7    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         3    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         3    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#       394    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#       394    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         5    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         5    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         5    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         5    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         6    0.000    0.000    0.000    0.000 typing.py:1374(__instancecheck__)
#        12    0.000    0.000    0.000    0.000 typing.py:1443(__hash__)
#         6    0.000    0.000    0.000    0.000 typing.py:1665(__subclasscheck__)
#       850    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#        18    0.000    0.000    0.000    0.000 typing.py:426(inner)
#         4    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         3    0.000    0.000    0.000    0.000 warnings.py:131(filterwarnings)
#         3    0.000    0.000    0.000    0.000 warnings.py:170(simplefilter)
#         6    0.000    0.000    0.000    0.000 warnings.py:188(_add_filter)
#         9    0.000    0.000    0.000    0.000 warnings.py:462(__init__)
#         9    0.000    0.000    0.000    0.000 warnings.py:488(__enter__)
#         9    0.000    0.000    0.000    0.000 warnings.py:509(__exit__)
#        12    0.000    0.000    0.000    0.000 zmqstream.py:528(receiving)
#         6    0.000    0.000    0.000    0.000 zmqstream.py:532(sending)
#         6    0.000    0.000    0.044    0.007 zmqstream.py:546(_run_callback)
#         6    0.000    0.000    0.077    0.013 zmqstream.py:573(_handle_events)
#         6    0.004    0.001    0.051    0.009 zmqstream.py:614(_handle_recv)
#         6    0.000    0.000    0.001    0.000 zmqstream.py:653(_rebuild_io_state)
#         6    0.000    0.000    0.001    0.000 zmqstream.py:676(_update_handler)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:684(<lambda>)
#        54    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10330fcf0}
#     88283    0.007    0.000    0.007    0.000 {built-in method _abc._abc_instancecheck}
#         6    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#       112    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#     88234    0.059    0.000    0.059    0.000 {built-in method _collections._count_elements}
#         4    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         6    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         3    0.005    0.002    0.005    0.002 {built-in method _io.open}
#        14    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        24    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#     13/12    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#       188    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    1.041    1.041 {built-in method builtins.exec}
#     88459    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#        67    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        37    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 177919/177889    0.015    0.000    0.029    0.000 {built-in method builtins.isinstance}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 289560/289510    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        87    0.000    0.000    0.034    0.000 {built-in method builtins.print}
#      4047    0.007    0.000    0.008    0.000 {built-in method builtins.sorted}
#        14    0.001    0.000    0.003    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         3    0.034    0.011    0.034    0.011 {built-in method gc.collect}
#        24    0.000    0.000    0.000    0.000 {built-in method math.gcd}
#         3    0.000    0.000    0.000    0.000 {built-in method now}
#        21    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        79    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        50    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#       192    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         6    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.check_pid_range}
#         6    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_kinfo_oneshot}
#         6    0.000    0.000    0.000    0.000 {built-in method psutil._psutil_osx.proc_pidtaskinfo_oneshot}
#         1    0.001    0.001    0.001    0.001 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#         1    0.004    0.004    0.004    0.004 {built-in method scipy.sparse._sparsetools.csr_diagonal}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#         2    0.068    0.034    0.068    0.034 {built-in method scipy.sparse._sparsetools.csr_matmat_maxnnz}
#         2    0.020    0.010    0.020    0.010 {built-in method scipy.sparse._sparsetools.csr_matmat}
#         1    0.002    0.002    0.002    0.002 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_sum_duplicates}
#         3    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#        20    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        12    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {function matrix.sum at 0x121e92020}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       235    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#    176474    0.014    0.000    0.014    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.001    0.001 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        17    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        48    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argpartition' of 'numpy.ndarray' objects}
#         1    0.004    0.004    0.004    0.004 {method 'argsort' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'as_integer_ratio' of 'float' objects}
#         2    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         3    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         8    0.294    0.037    0.336    0.042 {method 'control' of 'select.kqueue' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         6    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#     88234    0.007    0.000    0.007    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        15    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#     88234    0.006    0.000    0.006    0.000 {method 'find' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       174    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#     88335    0.007    0.000    0.007    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         9    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         6    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         3    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#       191    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#       294    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#    176468    0.013    0.000    0.013    0.000 {method 'pop' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#        15    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        13    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reduceat' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#     88234    0.007    0.000    0.007    0.000 {method 'rstrip' of 'str' objects}
#         9    0.000    0.000    0.090    0.010 {method 'run' of '_contextvars.Context' objects}
#    176474    0.015    0.000    0.015    0.000 {method 'split' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#    176468    0.009    0.000    0.009    0.000 {method 'strip' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#     88237    0.007    0.000    0.007    0.000 {method 'update' of 'dict' objects}
#        17    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       122    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#       174    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#
#
#
# Running Naive analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.21 seconds
# Memory Used: 4.44 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#
# Running NetworkX analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.23 seconds
# Memory Used: 3.42 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#
# Running SciPy Sparse analysis (1 runs)
# Nodes: 4039
# Edges: 88234
# Triangles: 1612010
# Average Degree: 43.69
# Density: 0.010820
# Execution Time: 0.19 seconds
# Memory Used: 15.09 MB
# Top 20 Most Connected Nodes:
#   Node 107: Degree 1045
#   Node 1684: Degree 792
#   Node 1912: Degree 755
#   Node 3437: Degree 547
#   Node 0: Degree 347
#   Node 2543: Degree 294
#   Node 2347: Degree 291
#   Node 1888: Degree 254
#   Node 1800: Degree 245
#   Node 1663: Degree 235
#   Node 1352: Degree 234
#   Node 2266: Degree 234
#   Node 483: Degree 231
#   Node 348: Degree 229
#   Node 1730: Degree 226
#   Node 1985: Degree 224
#   Node 1941: Degree 223
#   Node 2233: Degree 222
#   Node 2142: Degree 221
#   Node 1431: Degree 220
#
# Table: Performance Comparison (Averaged over runs)
#                 Method  Nodes  Edges  Triangles  Avg Degree  Density  \
# 0         Naive (Full)   4039  88234    1612010   43.691013  0.01082
# 1      NetworkX (Full)   4039  88234    1612010   43.691013  0.01082
# 2  SciPy Sparse (Full)   4039  88234    1612010   43.691013  0.01082
#
#    Time (s)  Time Std (s)  Memory (MB)  Memory Std (MB)
# 0  0.206441             0     4.437500                0
# 1  0.226304             0     3.421875                0
# 2  0.191538             0    15.093750                0
#
# Results saved to 01-01-graph_analysis_comparison.csv
# Top 20 nodes saved to 01-01-top_20_nodes.csv

# %% [markdown]
# ## Reference
#
# 1.
